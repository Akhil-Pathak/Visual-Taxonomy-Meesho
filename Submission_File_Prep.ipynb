# %%
import numpy as np
import pandas as pd
import os
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import glob

# %%
submission_file_Kurtis = './Inferencing/Kurtis/'
sub_kurtis = pd.read_csv(glob.glob(submission_file_Kurtis + '*.csv')[0])

submission_file_Women_Tshirts = './Inferencing/Women Tshirts/'
sub_women_tshirts = pd.read_csv(glob.glob(submission_file_Women_Tshirts + '*.csv')[0])

submission_file_Sarees = './Inferencing/Sarees/'
sub_sarees = pd.read_csv(glob.glob(submission_file_Sarees + '*.csv')[0])

submission_file_Men_Tshirts = './Inferencing/Men Tshirts/'
sub_men_tshirts = pd.read_csv(glob.glob(submission_file_Men_Tshirts + '*.csv')[0])

submission_file_Women_Tops_Tunics = './Inferencing/Women Tops & Tunics/'
sub_women_tops_tunics = pd.read_csv(glob.glob(submission_file_Women_Tops_Tunics + '*.csv')[0])

# %%
sub_kurtis['len'] = 9
sub_kurtis
# Out:
#          id Category  len      attr_1    attr_2       attr_3 attr_4 attr_5  \
# 0     11155   Kurtis    9         red  straight  knee length  daily    net
# 1     11156   Kurtis    9      purple    a-line  calf length  daily    net
# 2     11157   Kurtis    9       black    a-line  knee length  daily    net
# 3     11158   Kurtis    9  multicolor    a-line  knee length  daily    net
# 4     11159   Kurtis    9  multicolor    a-line  knee length  daily    net
# ...     ...      ...  ...         ...       ...          ...    ...    ...
# 2455  13610   Kurtis    9        blue    a-line  knee length  daily    net
# 2456  13611   Kurtis    9        blue    a-line  knee length  daily    net
# 2457  13612   Kurtis    9      maroon  straight  calf length  daily    net
# 2458  13613   Kurtis    9         red    a-line  calf length  daily    net
# 2459  13614   Kurtis    9        blue    a-line  calf length  daily    net
#
#      attr_6 attr_7                 attr_8   attr_9  attr_10
# ...

# %%
sub_women_tshirts['len'] = 8
sub_women_tshirts
# Out:
#          id       Category  len      attr_1   attr_2   attr_3   attr_4  \
# 0     13615  Women Tshirts    8       white  regular     long  printed
# 1     13616  Women Tshirts    8  multicolor  regular  regular  default
# 2     13617  Women Tshirts    8     default  regular  regular    solid
# 3     13618  Women Tshirts    8     default  regular  regular  printed
# 4     13619  Women Tshirts    8       black  regular     crop  printed
# ...     ...            ...  ...         ...      ...      ...      ...
# 9926  23559  Women Tshirts    8       white  regular  regular  printed
# 9927  23560  Women Tshirts    8     default  regular     crop  printed
# 9928  23561  Women Tshirts    8      yellow  regular     crop  printed
# 9929  23562  Women Tshirts    8       white  regular  regular  printed
# 9930  23563  Women Tshirts    8       white    loose     long  printed
#
#            attr_5         attr_6           attr_7   attr_8 attr_9 attr_10
# ...

# %%
sub_sarees['len'] = 10
sub_sarees
# Out:
#          id Category  len          attr_1        attr_2        attr_3  \
# 0      3787   Sarees   10         default       default  small border
# 1      3788   Sarees   10  same as border  woven design    big border
# 2      3789   Sarees   10           solid          zari    big border
# 3      3790   Sarees   10  same as border  woven design    big border
# 4      3791   Sarees   10         default  woven design     no border
# ...     ...      ...  ...             ...           ...           ...
# 7097  11150   Sarees   10         default  woven design     no border
# 7098  11151   Sarees   10  same as border          zari    big border
# 7099  11152   Sarees   10   same as saree  woven design    big border
# 7100  11153   Sarees   10   same as saree  woven design    big border
# 7101  11154   Sarees   10   same as saree          zari  small border
#
#           attr_4       attr_5    attr_6         attr_7      attr_8  \
# ...

# %%
sub_men_tshirts['len'] = 5
sub_men_tshirts
# Out:
#         id     Category  len      attr_1 attr_2   attr_3      attr_4  \
# 0        0  Men Tshirts    5  multicolor  round  printed     default
# 1        1  Men Tshirts    5       white  round  printed  typography
# 2        2  Men Tshirts    5       white  round  printed     default
# 3        3  Men Tshirts    5     default   polo    solid       solid
# 4        4  Men Tshirts    5       black  round    solid       solid
# ...    ...          ...  ...         ...    ...      ...         ...
# 3782  3782  Men Tshirts    5     default   polo    solid       solid
# 3783  3783  Men Tshirts    5       black  round  printed     default
# 3784  3784  Men Tshirts    5     default   polo  printed     default
# 3785  3785  Men Tshirts    5     default  round    solid       solid
# 3786  3786  Men Tshirts    5     default   polo    solid       solid
#
#              attr_5  attr_6  attr_7  attr_8  attr_9  attr_10
# 0      long sleeves     NaN     NaN     NaN     NaN      NaN
# ...

# %%
sub_women_tops_tunics['len'] = 10
sub_women_tops_tunics
# Out:
#          id             Category  len      attr_1   attr_2   attr_3  \
# 0     23564  Women Tops & Tunics   10   navy blue   fitted     crop
# 1     23565  Women Tops & Tunics   10      yellow     boxy     crop
# 2     23566  Women Tops & Tunics   10       black   fitted  regular
# 3     23567  Women Tops & Tunics   10        pink  regular  regular
# 4     23568  Women Tops & Tunics   10       black   fitted  regular
# ...     ...                  ...  ...         ...      ...      ...
# 6920  30484  Women Tops & Tunics   10       green     boxy     crop
# 6921  30485  Women Tops & Tunics   10     default  regular  regular
# 6922  30486  Women Tops & Tunics   10     default  regular  regular
# 6923  30487  Women Tops & Tunics   10  multicolor  regular  regular
# 6924  30488  Women Tops & Tunics   10        pink   fitted     crop
#
#           attr_4  attr_5   attr_6      attr_7         attr_8           attr_9  \
# ...

# %%
final_submission = pd.concat([sub_kurtis, sub_women_tshirts, sub_sarees, sub_men_tshirts, sub_women_tops_tunics], ignore_index=True)
final_submission = final_submission.fillna('dummy')
final_submission = final_submission.sort_values(by='id')
final_submission = final_submission.reset_index(drop=True)
final_submission.to_csv('submission.csv', index=False)
final_submission
# Out:
#           id             Category  len      attr_1   attr_2   attr_3  \
# 0          0          Men Tshirts    5  multicolor    round  printed
# 1          1          Men Tshirts    5       white    round  printed
# 2          2          Men Tshirts    5       white    round  printed
# 3          3          Men Tshirts    5     default     polo    solid
# 4          4          Men Tshirts    5       black    round    solid
# ...      ...                  ...  ...         ...      ...      ...
# 30200  30484  Women Tops & Tunics   10       green     boxy     crop
# 30201  30485  Women Tops & Tunics   10     default  regular  regular
# 30202  30486  Women Tops & Tunics   10     default  regular  regular
# 30203  30487  Women Tops & Tunics   10  multicolor  regular  regular
# 30204  30488  Women Tops & Tunics   10        pink   fitted     crop
#
#            attr_4         attr_5   attr_6      attr_7         attr_8  \
# ...
